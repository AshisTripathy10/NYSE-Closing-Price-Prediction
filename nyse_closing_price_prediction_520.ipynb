# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/cxldata/datasets/project/ny_stock_prediction/prices-split-adjusted.csv', header = 0)
df.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
df.shape
# Out:
# (851264, 7)

# %%
df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
#        'DFS', 'DG', 'DGX', 'DHI', 'DHR', 'DIS', 'DISCA', 'DISCK', 'DLR',
#        'DLTR', 'DNB', 'DOV', 'DOW', 'DPS', 'DRI', 'DTE', 'DUK', 'DVA',
#        'DVN', 'EA', 'EBAY', 'ECL', 'ED', 'EFX', 'EIX', 'EL', 'EMN', 'EMR',
#        'ENDP', 'EOG', 'EQIX', 'EQR', 'EQT', 'ES', 'ESRX', 'ESS', 'ETFC',
#        'ETN', 'ETR', 'EW', 'EXC', 'EXPD', 'EXPE', 'EXR', 'F', 'FAST',
#        'FCX', 'FDX', 'FE', 'FFIV', 'FIS', 'FISV', 'FITB', 'FL', 'FLIR',
#        'FLR', 'FLS', 'FMC', 'FOX', 'FOXA', 'FRT', 'FSLR', 'FTI', 'FTR',
#        'GD', 'GE', 'GGP', 'GILD', 'GIS', 'GLW', 'GOOG', 'GOOGL', 'GPC',
#        'GPN', 'GPS', 'GRMN', 'GS', 'GT', 'GWW', 'HAL', 'HAR', 'HAS',
#        'HBAN', 'HBI', 'HCN', 'HCP', 'HD', 'HES', 'HIG', 'HOG', 'HOLX',
#        'HON', 'HP', 'HPQ', 'HRB', 'HRL', 'HRS', 'HSIC', 'HST', 'HSY',
#        'HUM', 'IBM', 'ICE', 'IDXX', 'IFF', 'ILMN', 'INTC', 'INTU', 'IP',
#        'IPG', 'IR', 'IRM', 'ISRG', 'ITW', 'IVZ', 'JBHT', 'JCI', 'JEC',
#        'JNJ', 'JNPR', 'JPM', 'JWN', 'K', 'KEY', 'KIM', 'KLAC', 'KMB',
#        'KMX', 'KO', 'KR', 'KSS', 'KSU', 'L', 'LB', 'LEG', 'LEN', 'LH',
#        'LKQ', 'LLL', 'LLTC', 'LLY', 'LMT', 'LNC', 'LNT', 'LOW', 'LRCX',
#        'LUK', 'LUV', 'LVLT', 'M', 'MA', 'MAA', 'MAC', 'MAR', 'MAS', 'MAT',
#        'MCD', 'MCHP', 'MCK', 'MCO', 'MDLZ', 'MDT', 'MET', 'MHK', 'MJN',
#        'MKC', 'MLM', 'MMC', 'MMM', 'MNST', 'MO', 'MON', 'MOS', 'MRK',
#        'MRO', 'MSFT', 'MSI', 'MTB', 'MTD', 'MU', 'MUR', 'MYL', 'NBL',
#        'NDAQ', 'NEE', 'NEM', 'NFLX', 'NFX', 'NI', 'NKE', 'NOC', 'NOV',
#        'NRG', 'NSC', 'NTAP', 'NTRS', 'NUE', 'NVDA', 'NWL', 'O', 'OKE',
#        'OMC', 'ORCL', 'ORLY', 'OXY', 'PAYX', 'PBCT', 'PBI', 'PCAR', 'PCG',
#        'PCLN', 'PDCO', 'PEG', 'PEP', 'PFE', 'PFG', 'PG', 'PGR', 'PH',
#        'PHM', 'PKI', 'PLD', 'PM', 'PNC', 'PNR', 'PNW', 'PPG', 'PPL',
#        'PRGO', 'PRU', 'PSA', 'PVH', 'PWR', 'PX', 'PXD', 'QCOM', 'R',
#        'RAI', 'RCL', 'REGN', 'RF', 'RHI', 'RHT', 'RIG', 'RL', 'ROK',
#        'ROP', 'ROST', 'RRC', 'RSG', 'RTN', 'SBUX', 'SCG', 'SCHW', 'SE',
#        'SEE', 'SHW', 'SIG', 'SJM', 'SLB', 'SLG', 'SNA', 'SNI', 'SO',
#        'SPG', 'SPGI', 'SPLS', 'SRCL', 'SRE', 'STI', 'STT', 'STX', 'STZ',
#        'SWK', 'SWKS', 'SWN', 'SYK', 'SYMC', 'SYY', 'T', 'TAP', 'TDC',
#        'TEL', 'TGNA', 'TGT', 'TIF', 'TJX', 'TMK', 'TMO', 'TROW', 'TRV',
#        'TSCO', 'TSN', 'TSO', 'TSS', 'TWX', 'TXN', 'TXT', 'UAA', 'UAL',
#        'UDR', 'UHS', 'ULTA', 'UNH', 'UNM', 'UNP', 'UPS', 'URBN', 'URI',
#        'USB', 'UTX', 'V', 'VAR', 'VFC', 'VIAB', 'VLO', 'VMC', 'VNO',
#        'VRSK', 'VRSN', 'VRTX', 'VTR', 'VZ', 'WAT', 'WBA', 'WDC', 'WEC',
#        'WFC', 'WFM', 'WHR', 'WM', 'WMB', 'WMT', 'WU', 'WY', 'WYN', 'WYNN',
#        'XEC', 'XEL', 'XL', 'XLNX', 'XOM', 'XRAY', 'XRX', 'YHOO', 'YUM',
#        'ZBH', 'ZION', 'AIV', 'CHTR', 'LYB', 'GM', 'ABBV', 'DLPH', 'FB',
#        'FBHS', 'HCA', 'KMI', 'KORS', 'MPC', 'NLSN', 'PSX', 'TDG', 'TRIP',
#        'XYL', 'ZTS', 'COTY', 'MNK', 'NWS', 'NWSA', 'EVHC', 'ALLE', 'CFG',
#        'NAVI', 'QRVO', 'SYF', 'WRK', 'KHC', 'PYPL', 'HPE', 'CSRA', 'FTV'],
#       dtype=object)

# %%
cod = 'YHOO'
df_yahoo = df[df['symbol']== cod]

# %%
df_yahoo.head(35)
# Out:
#              date symbol       open      close        low       high  \
# 713    2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001
# 1181   2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000
# 1649   2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999
# 2117   2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000
# 2585   2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000
# 3053   2010-01-11   YHOO  16.770000  16.740000  16.480000  16.830000
# 3521   2010-01-12   YHOO  16.650000  16.680000  16.600000  16.860001
# 3989   2010-01-13   YHOO  16.879999  16.900000  16.650000  16.980000
# 4457   2010-01-14   YHOO  16.809999  17.120001  16.799999  17.230000
# 4925   2010-01-15   YHOO  17.250000  16.820000  16.750000  17.250000
# 5393   2010-01-19   YHOO  16.780001  16.750000  16.639999  16.959999
# 5861   2010-01-20   YHOO  16.650000  16.379999  16.250000  16.680000
# 6329   2010-01-21   YHOO  16.389999  16.200001  16.100000  16.580000
# 6797   2010-01-22   YHOO  16.080000  15.880000  15.810000  16.209999
# 7265   2010-01-25   YHOO  16.070000  15.860000  15.740000  16.110001
# 7733   2010-01-26   YHOO  15.820000  15.990000  15.700000  16.170000
# 8201   2010-01-27   YHOO  16.459999  15.980000  15.770000  16.490000
# 8669   2010-01-28   YHOO  15.930000  15.440000  15.440000  15.960000
# 9137   2010-01-29   YHOO  15.510000  15.010000  14.900000  15.670000
# 9605   2010-02-01   YHOO  15.140000  15.050000  14.870000  15.300000
# 10073  2010-02-02   YHOO  15.100000  15.170000  15.030000  15.320000
# 10541  2010-02-03   YHOO  15.120000  15.460000  15.120000  15.600000
# 11009  2010-02-04   YHOO  15.340000  15.010000  14.990000  15.520000
# 11477  2010-02-05   YHOO  15.010000  15.190000  14.920000  15.250000
# 11945  2010-02-08   YHOO  15.180000  14.990000  14.950000  15.470000
# 12413  2010-02-09   YHOO  15.200000  15.070000  14.940000  15.240000
# 12881  2010-02-10   YHOO  15.020000  14.800000  14.480000  15.020000
# 13349  2010-02-11   YHOO  14.870000  15.220000  14.770000  15.250000
# 13817  2010-02-12   YHOO  15.070000  15.170000  14.850000  15.190000
# 14285  2010-02-16   YHOO  15.230000  15.410000  15.180000  15.480000
# 14753  2010-02-17   YHOO  15.500000  15.440000  15.320000  15.520000
# 15221  2010-02-18   YHOO  15.400000  15.540000  15.320000  15.600000
# 15689  2010-02-19   YHOO  15.490000  15.580000  15.330000  15.710000
# 16157  2010-02-22   YHOO  15.610000  15.490000  15.440000  15.680000
# 16625  2010-02-23   YHOO  15.450000  15.380000  15.140000  15.510000
#
#            volume
# 713    16587400.0
# 1181   11718100.0
# 1649   16422000.0
# 2117   31816300.0
# 2585   15470000.0
# 3053   16181900.0
# 3521   15672400.0
# 3989   16955600.0
# 4457   16715600.0
# 4925   18415000.0
# 5393   15182600.0
# 5861   14419500.0
# 6329   21858400.0
# 6797   25132800.0
# 7265   19683700.0
# 7733   43979400.0
# 8201   41701000.0
# 8669   30159500.0
# 9137   39664600.0
# 9605   29865700.0
# 10073  27555200.0
# 10541  24730600.0
# 11009  27668100.0
# 11477  20713800.0
# 11945  19856400.0
# 12413  16716900.0
# 12881  36518100.0
# 13349  24509500.0
# 13817  18926400.0
# 14285  21447200.0
# 14753  12731900.0
# 15221  13700100.0
# 15689  15407900.0
# 16157  10463500.0
# 16625  18346700.0

# %%
df_yahoo.shape
# Out:
# (1762, 7)

# %%
df_yahoo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1762 entries, 713 to 851257
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1762 non-null   object
#  1   symbol  1762 non-null   object
#  2   open    1762 non-null   float64
#  3   close   1762 non-null   float64
#  4   low     1762 non-null   float64
#  5   high    1762 non-null   float64
#  6   volume  1762 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 110.1+ KB

# %%
df_yahoo.describe()
# Out:
#               open        close          low         high        volume
# count  1762.000000  1762.000000  1762.000000  1762.000000  1.762000e+03
# mean     27.297917    27.291992    26.975602    27.609977  1.996907e+07
# std      11.412612    11.406846    11.289736    11.526101  1.376851e+07
# min      11.300000    11.090000    11.090000    11.800000  2.586900e+06
# 25%      15.950000    15.920000    15.770000    16.110001  1.235152e+07
# 50%      26.770001    26.750000    26.495000    27.105001  1.639070e+07
# 75%      37.335000    37.377501    36.897501    37.689999  2.325988e+07
# max      52.279999    52.369999    51.639999    52.619999  2.338721e+08

# %%
df_yahoo.isnull().sum()
# Out:
# date      0
# symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64

# %%
df_yahoo.head()
df_yahoo['date'] = pd.to_datetime(df_yahoo['date'])
# Out:
# /usr/local/anaconda/envs/tensorflow2/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(df_yahoo.date.dtype)
# Out:
# datetime64[ns]

# %%
df_yahoo = df_yahoo.set_index('date')

# %%
df_yahoo.head()
# Out:
#            symbol       open      close        low       high      volume
# date
# 2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200
NaN   NaN    NaN  NaN   NaN     NaN
# 2011-01-17    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-02-21    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-04-22    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-05-30    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-07-04    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-09-05    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-11-24    NaN   NaN    NaN  NaN   NaN     NaN
# 2011-12-26    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-01-02    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-01-16    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-02-20    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-04-06    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-05-28    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-07-04    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-09-03    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-10-29    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-10-30    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-11-22    NaN   NaN    NaN  NaN   NaN     NaN
# 2012-12-25    NaN   NaN    NaN  NaN   NaN     NaN
# 2013-01-01    NaN   NaN    NaN  NaN   NaN     NaN
# 2013-01-21    NaN   NaN    NaN  NaN   NaN     NaN
# 2013-02-18    NaN   NaN    NaN  NaN   NaN     NaN

# %%
null_dates = null_data.index.tolist()

# %%
null_dates
# Out:
# [Timestamp('2010-01-18 00:00:00'),
#  Timestamp('2010-02-15 00:00:00'),
#  Timestamp('2010-04-02 00:00:00'),
#  Timestamp('2010-05-31 00:00:00'),
#  Timestamp('2010-07-05 00:00:00'),
#  Timestamp('2010-09-06 00:00:00'),
#  Timestamp('2010-11-25 00:00:00'),
#  Timestamp('2010-12-24 00:00:00'),
#  Timestamp('2011-01-17 00:00:00'),
#  Timestamp('2011-02-21 00:00:00'),
#  Timestamp('2011-04-22 00:00:00'),
#  Timestamp('2011-05-30 00:00:00'),
#  Timestamp('2011-07-04 00:00:00'),
#  Timestamp('2011-09-05 00:00:00'),
#  Timestamp('2011-11-24 00:00:00'),
#  Timestamp('2011-12-26 00:00:00'),
#  Timestamp('2012-01-02 00:00:00'),
#  Timestamp('2012-01-16 00:00:00'),
#  Timestamp('2012-02-20 00:00:00'),
#  Timestamp('2012-04-06 00:00:00'),
#  Timestamp('2012-05-28 00:00:00'),
#  Timestamp('2012-07-04 00:00:00'),
#  Timestamp('2012-09-03 00:00:00'),
#  Timestamp('2012-10-29 00:00:00'),
#  Timestamp('2012-10-30 00:00:00'),
#  Timestamp('2012-11-22 00:00:00'),
#  Timestamp('2012-12-25 00:00:00'),
#  Timestamp('2013-01-01 00:00:00'),
#  Timestamp('2013-01-21 00:00:00'),
#  Timestamp('2013-02-18 00:00:00'),
#  Timestamp('2013-03-29 00:00:00'),
#  Timestamp('2013-05-27 00:00:00'),
#  Timestamp('2013-07-04 00:00:00'),
#  Timestamp('2013-09-02 00:00:00'),
#  Timestamp('2013-11-28 00:00:00'),
#  Timestamp('2013-12-25 00:00:00'),
#  Timestamp('2014-01-01 00:00:00'),
#  Timestamp('2014-01-20 00:00:00'),
#  Timestamp('2014-02-17 00:00:00'),
#  Timestamp('2014-04-18 00:00:00'),
#  Timestamp('2014-05-26 00:00:00'),
#  Timestamp('2014-07-04 00:00:00'),
#  Timestamp('2014-09-01 00:00:00'),
#  Timestamp('2014-11-27 00:00:00'),
#  Timestamp('2014-12-25 00:00:00'),
#  Timestamp('2015-01-01 00:00:00'),
#  Timestamp('2015-01-19 00:00:00'),
#  Timestamp('2015-02-16 00:00:00'),
#  Timestamp('2015-04-03 00:00:00'),
#  Timestamp('2015-05-25 00:00:00'),
#  Timestamp('2015-07-03 00:00:00'),
#  Timestamp('2015-09-07 00:00:00'),
#  Timestamp('2015-11-26 00:00:00'),
#  Timestamp('2015-12-25 00:00:00'),
#  Timestamp('2016-01-01 00:00:00'),
#  Timestamp('2016-01-18 00:00:00'),
#  Timestamp('2016-02-15 00:00:00'),
#  Timestamp('2016-03-25 00:00:00'),
#  Timestamp('2016-05-30 00:00:00'),
#  Timestamp('2016-07-04 00:00:00'),
#  Timestamp('2016-09-05 00:00:00'),
#  Timestamp('2016-11-24 00:00:00'),
#  Timestamp('2016-12-26 00:00:00')]

# %%
import calendar
import datetime

holidays = []

for date in null_dates:
    week, day, month, year = date.weekday(), date.day, date.month, date.year
    week_day = calendar.day_name[week]

    if month==1:
        if day==1:
            # New year day
            holidays.append(date)
        elif day==2 and week_day=='Monday':
            # Observed New Year Day
            holidays.append(date)
        elif day>=15 and day<=21 and week_day=='Monday':
            # Martin Luther King, Jr. Day
            holidays.append(date)

    elif month==2:
        # Washington's Birthday
        if day>=15 and day<=21 and week_day=='Monday':
            holidays.append(date)

    elif month==5:
        # Memorial day
        if day>=25 and day<=31 and week_day=='Monday':
            holidays.append(date)

    elif month==7:
        # Independence day
        if day==4:
            holidays.append(date)
        # Observed Independence  Day
        elif day==5 and week_day=='Monday':
            holidays.append(date)
        elif day==3 and week_day=='Friday':
            holidays.append(date)

    elif month == 9:
        # Labour day
        if day>=1 and day<=7 and week_day=='Monday':
            holidays.append(date)

    elif month==11:
        # Thanksgiving Day
        if week_day=='Thursday' and day>=22 and day<=28:
            holidays.append(date)

    elif month==12:
        # Christmas Day
        if day==25:
            holidays.append(date)
        # Observed Christmas Day
        elif day==24 and week_day=='Friday':
            holidays.append(date)
        elif day==26 and week_day=='Monday':
            holidays.append(date)

good_fridays = [ datetime.date(2010,4,2), datetime.date(2011,4,22), datetime.date(2012,4,6), datetime.date(2013,3,29), datetime.date(2014,4,18), datetime.date(2015,4,3), datetime.date(2016,3,25) ]
holidays = holidays + [pd.to_datetime(date) for date in good_fridays]

non_holidays = [x for x in null_dates if x not in holidays]
print(non_holidays)
# Out:
# [Timestamp('2012-10-29 00:00:00'), Timestamp('2012-10-30 00:00:00')]

# %%
yahoo_data.shape
# Out:
# (1825, 6)

# %%
# Find the intersection of holidays and yahoo_data's index (dates that are both present)
common_holidays = yahoo_data.index.intersection(holidays)

# Drop only the holidays that are present in yahoo_data
modified_df = yahoo_data.drop(common_holidays)

# %%
modified_df.shape
# Out:
# (1764, 6)

# %%
print("Before filling missing values:\n", modified_df.isna().sum())
# Out:
# Before filling missing values:
#  symbol    2
# open      2
# close     2
# low       2
# high      2
# volume    2
# dtype: int64

# %%
modified_df = modified_df.bfill(axis='rows')

# %%
print("\nAfter filling missing values:\n",modified_df.isna().sum())
modified_df.head(10)
# Out:
# After filling missing values:
#  symbol    0
# open      0
# close     0
# low       0
# high      0
# volume    0
# dtype: int64
#            symbol       open      close        low       high      volume
# date
# 2010-01-04   YHOO  16.940001  17.100000  16.879999  17.200001  16587400.0
# 2010-01-05   YHOO  17.219999  17.230000  17.000000  17.230000  11718100.0
# 2010-01-06   YHOO  17.170000  17.170000  17.070000  17.299999  16422000.0
# 2010-01-07   YHOO  16.809999  16.700001  16.570000  16.900000  31816300.0
# 2010-01-08   YHOO  16.680000  16.700001  16.620001  16.760000  15470000.0
# 2010-01-11   YHOO  16.770000  16.740000  16.480000  16.830000  16181900.0
# 2010-01-12   YHOO  16.650000  16.680000  16.600000  16.860001  15672400.0
# 2010-01-13   YHOO  16.879999  16.900000  16.650000  16.980000  16955600.0
# 2010-01-14   YHOO  16.809999  17.120001  16.799999  17.230000  16715600.0
# 2010-01-15   YHOO  17.250000  16.820000  16.750000  17.250000  18415000.0

# %%
def plotter(code):
    global closing_stock
    plt.subplot(211)
    company_close = modified_df[modified_df['symbol']==code]
    company_close = company_close.close.values.astype('float32')
    company_close = company_close.reshape(-1, 1)
    closing_stock = company_close
    plt.xlabel('Time')
    plt.ylabel(code + " close stock prices")
    plt.title('prices Vs Time')
    plt.grid(True)
    plt.plot(company_close , 'b')
    plt.show()

plotter(cod)

# %%
n_train = int(len(closing_stock) * 0.80)
n_remaining = len(closing_stock) - n_train

n_val = int(n_remaining*0.50)
n_test = n_remaining - n_val 
print("Train samples:",n_train, "Validation Samples:",n_val,"Test Samples:", n_test)
# Out:
# Train samples: 1411 Validation Samples: 176 Test Samples: 177

# %%
train_data = closing_stock[0:n_train]
print(train_data.shape)
# Out:
# (1411, 1)

# %%
val_data = closing_stock[n_train:n_train+n_val]
print(val_data.shape)
# Out:
# (176, 1)

# %%
test_data = closing_stock[n_train+n_val:]
print(test_data.shape)
# Out:
# (177, 1)

# %%
print(train_data[0:10])
# Out:
# [[17.1 ]
#  [17.23]
#  [17.17]
#  [16.7 ]
#  [16.7 ]
#  [16.74]
#  [16.68]
#  [16.9 ]
#  [17.12]
#  [16.82]]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0,1))
train = scaler.fit_transform(train_data)
val = scaler.transform(val_data)
test = scaler.transform(test_data)

# %%
def create_dataset(data , n_features):
    dataX, dataY = [], []
    for i in range(len(data)-n_features-1):
        a = data[i:(i+n_features), 0]
        dataX.append(a)
        dataY.append(data[i + n_features, 0])
    return np.array(dataX), np.array(dataY)

# %%
n_features = 1
trainX, trainY = create_dataset(train, n_features)
valX, valY = create_dataset(val, n_features)
testX, testY = create_dataset(test, n_features)

# %%
print(trainX.shape , trainY.shape , valX.shape , valY.shape, testX.shape , testY.shape)
# Out:
# (1409, 1) (1409,) (174, 1) (174,) (175, 1) (175,)

# %%
trainX = trainX.reshape(trainX.shape[0] , 1 ,trainX.shape[1])
valX = valX.reshape(valX.shape[0] , 1 ,valX.shape[1])
testX = testX.reshape(testX.shape[0] , 1 ,testX.shape[1])

# %%
print(trainX.shape , trainY.shape , valX.shape , valY.shape, testX.shape , testY.shape)
# Out:
# (1409, 1, 1) (1409,) (174, 1, 1) (174,) (175, 1, 1) (175,)

# %%
import tensorflow as tf
tf.random.set_seed(42)

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import Nadam

# %%
model=keras.Sequential()

# %%
# First GRU layer
model.add(layers.GRU(units=100, return_sequences=True, input_shape=(1,n_features), activation='tanh'))
model.add(layers.Dropout(0.2))

# Second GRU layer
model.add(layers.GRU(units=150, return_sequences=True, input_shape=(1,n_features), activation='tanh'))
model.add(layers.Dropout(0.2))

# Third GRU layer
model.add(layers.GRU(units=100, activation='tanh'))
model.add(layers.Dropout(0.2))

# The output layer
model.add(layers.Dense(units=1, kernel_initializer='he_uniform', activation='linear'))

# %%
model.compile(loss='mean_squared_error', optimizer=Nadam(lr = 0.0005) , metrics = ['mean_squared_error'])
# Out:
# /usr/local/anaconda/envs/tensorflow2/lib/python3.6/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 1, 100)            30900
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 100)            0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 1, 150)            113400
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1, 150)            0
# _________________________________________________________________
# gru_2 (GRU)                  (None, 100)               75600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 101
# =================================================================
# Total params: 220,001
# Trainable params: 220,001
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history = model.fit(trainX,trainY,epochs=100,batch_size=128, verbose=1, validation_data = (valX,valY))
# Out:
# Epoch 1/100
# 12/12 [==============================] - 7s 108ms/step - loss: 0.1527 - mean_squared_error: 0.1527 - val_loss: 0.1354 - val_mean_squared_error: 0.1354
# Epoch 2/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0609 - mean_squared_error: 0.0609 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 3/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0278 - mean_squared_error: 0.0278 - val_loss: 0.0050 - val_mean_squared_error: 0.0050
# Epoch 4/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0019 - val_mean_squared_error: 0.0019
# Epoch 5/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 6/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 7.8309e-04 - val_mean_squared_error: 7.8309e-04
# Epoch 7/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 7.3811e-04 - val_mean_squared_error: 7.3811e-04
# Epoch 8/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 4.4996e-04 - val_mean_squared_error: 4.4996e-04
# Epoch 9/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 4.4357e-04 - val_mean_squared_error: 4.4357e-04
# Epoch 10/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 3.9984e-04 - val_mean_squared_error: 3.9984e-04
# Epoch 11/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 4.2569e-04 - val_mean_squared_error: 4.2569e-04
# Epoch 12/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 5.9893e-04 - val_mean_squared_error: 5.9893e-04
# Epoch 13/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 4.7889e-04 - val_mean_squared_error: 4.7889e-04
# Epoch 14/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 3.5023e-04 - val_mean_squared_error: 3.5023e-04
# Epoch 15/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 4.3763e-04 - val_mean_squared_error: 4.3763e-04
# Epoch 16/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0065 - val_mean_squared_error: 0.0065
# Epoch 17/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 3.4676e-04 - val_mean_squared_error: 3.4676e-04
# Epoch 18/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0057 - val_mean_squared_error: 0.0057
# Epoch 19/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0023 - mean_squared_error: 0.0023 - val_loss: 3.4373e-04 - val_mean_squared_error: 3.4373e-04
# Epoch 20/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 21/100
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 6.6623e-04 - val_mean_squared_error: 6.6623e-04
# Epoch 22/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 4.5875e-04 - val_mean_squared_error: 4.5875e-04
# Epoch 23/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 6.2535e-04 - val_mean_squared_error: 6.2535e-04
# Epoch 24/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 3.5560e-04 - val_mean_squared_error: 3.5560e-04
# Epoch 25/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 6.4921e-04 - val_mean_squared_error: 6.4921e-04
# Epoch 26/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 0.0080 - val_mean_squared_error: 0.0080
# Epoch 27/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 28/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 4.2651e-04 - val_mean_squared_error: 4.2651e-04
# Epoch 29/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 3.4882e-04 - val_mean_squared_error: 3.4882e-04
# Epoch 30/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 5.0288e-04 - val_mean_squared_error: 5.0288e-04
# Epoch 31/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 7.5196e-04 - val_mean_squared_error: 7.5196e-04
# Epoch 32/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0047 - val_mean_squared_error: 0.0047
# Epoch 33/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 8.9651e-04 - val_mean_squared_error: 8.9651e-04
# Epoch 34/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 3.3912e-04 - val_mean_squared_error: 3.3912e-04
# Epoch 35/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 4.0070e-04 - val_mean_squared_error: 4.0070e-04
# Epoch 36/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 5.1863e-04 - val_mean_squared_error: 5.1863e-04
# Epoch 37/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 3.4139e-04 - val_mean_squared_error: 3.4139e-04
# Epoch 38/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 5.2636e-04 - val_mean_squared_error: 5.2636e-04
# Epoch 39/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.4821e-04 - val_mean_squared_error: 3.4821e-04
# Epoch 40/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0098 - val_mean_squared_error: 0.0098
# Epoch 41/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0020 - mean_squared_error: 0.0020 - val_loss: 8.1654e-04 - val_mean_squared_error: 8.1654e-04
# Epoch 42/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 9.8426e-04 - val_mean_squared_error: 9.8426e-04
# Epoch 43/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.3563e-04 - val_mean_squared_error: 3.3563e-04
# Epoch 44/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.6458e-04 - val_mean_squared_error: 7.6458e-04
# Epoch 45/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.8849e-04 - val_mean_squared_error: 3.8849e-04
# Epoch 46/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 47/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0037 - val_mean_squared_error: 0.0037
# Epoch 48/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 5.2350e-04 - val_mean_squared_error: 5.2350e-04
# Epoch 49/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0159 - val_mean_squared_error: 0.0159
# Epoch 50/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 4.3022e-04 - val_mean_squared_error: 4.3022e-04
# Epoch 51/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.5950e-04 - val_mean_squared_error: 3.5950e-04
# Epoch 52/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.8263e-04 - val_mean_squared_error: 3.8263e-04
# Epoch 53/100
# 12/12 [==============================] - 0s 14ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.3966e-04 - val_mean_squared_error: 3.3966e-04
# Epoch 54/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.6779e-04 - val_mean_squared_error: 3.6779e-04
# Epoch 55/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.6130e-04 - val_mean_squared_error: 3.6130e-04
# Epoch 56/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 6.1882e-04 - val_mean_squared_error: 6.1882e-04
# Epoch 57/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0074 - val_mean_squared_error: 0.0074
# Epoch 58/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0019 - mean_squared_error: 0.0019 - val_loss: 3.3440e-04 - val_mean_squared_error: 3.3440e-04
# Epoch 59/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 4.6680e-04 - val_mean_squared_error: 4.6680e-04
# Epoch 60/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 61/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.3409e-04 - val_mean_squared_error: 3.3409e-04
# Epoch 62/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 4.4921e-04 - val_mean_squared_error: 4.4921e-04
# Epoch 63/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 4.6050e-04 - val_mean_squared_error: 4.6050e-04
# Epoch 64/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.9148e-04 - val_mean_squared_error: 3.9148e-04
# Epoch 65/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 3.4728e-04 - val_mean_squared_error: 3.4728e-04
# Epoch 66/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 5.7591e-04 - val_mean_squared_error: 5.7591e-04
# Epoch 67/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.2965e-04 - val_mean_squared_error: 3.2965e-04
# Epoch 68/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.4397e-04 - val_mean_squared_error: 3.4397e-04
# Epoch 69/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 4.1323e-04 - val_mean_squared_error: 4.1323e-04
# Epoch 70/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 71/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 72/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0016 - mean_squared_error: 0.0016 - val_loss: 3.7323e-04 - val_mean_squared_error: 3.7323e-04
# Epoch 73/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.2454e-04 - val_mean_squared_error: 4.2454e-04
# Epoch 74/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 75/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 7.0512e-04 - val_mean_squared_error: 7.0512e-04
# Epoch 76/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.8640e-04 - val_mean_squared_error: 5.8640e-04
# Epoch 77/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 4.8886e-04 - val_mean_squared_error: 4.8886e-04
# Epoch 78/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 3.4284e-04 - val_mean_squared_error: 3.4284e-04
# Epoch 79/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.7305e-04 - val_mean_squared_error: 3.7305e-04
# Epoch 80/100
# 12/12 [==============================] - 0s 15ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.9794e-04 - val_mean_squared_error: 3.9794e-04
# Epoch 81/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.3269e-04 - val_mean_squared_error: 3.3269e-04
# Epoch 82/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.8440e-04 - val_mean_squared_error: 3.8440e-04
# Epoch 83/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.9786e-04 - val_mean_squared_error: 3.9786e-04
# Epoch 84/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.5639e-04 - val_mean_squared_error: 3.5639e-04
# Epoch 85/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.2320e-04 - val_mean_squared_error: 5.2320e-04
# Epoch 86/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.6795e-04 - val_mean_squared_error: 3.6795e-04
# Epoch 87/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.4501e-04 - val_mean_squared_error: 3.4501e-04
# Epoch 88/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.6229e-04 - val_mean_squared_error: 3.6229e-04
# Epoch 89/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 6.6551e-04 - val_mean_squared_error: 6.6551e-04
# Epoch 90/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 4.2516e-04 - val_mean_squared_error: 4.2516e-04
# Epoch 91/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.3422e-04 - val_mean_squared_error: 3.3422e-04
# Epoch 92/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 4.5669e-04 - val_mean_squared_error: 4.5669e-04
# Epoch 93/100
# 12/12 [==============================] - 0s 11ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 5.1780e-04 - val_mean_squared_error: 5.1780e-04
# Epoch 94/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.2548e-04 - val_mean_squared_error: 3.2548e-04
# Epoch 95/100
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.3609e-04 - val_mean_squared_error: 3.3609e-04
# Epoch 96/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.3843e-04 - val_mean_squared_error: 9.3843e-04
# Epoch 97/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 4.9011e-04 - val_mean_squared_error: 4.9011e-04
# Epoch 98/100
# 12/12 [==============================] - 0s 13ms/step - loss: 9.9422e-04 - mean_squared_error: 9.9422e-04 - val_loss: 3.4061e-04 - val_mean_squared_error: 3.4061e-04
# Epoch 99/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0012 - mean_squared_error: 0.0012 - val_loss: 3.9865e-04 - val_mean_squared_error: 3.9865e-04
# Epoch 100/100
# 12/12 [==============================] - 0s 12ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 3.3626e-04 - val_mean_squared_error: 3.3626e-04

# %%
import math

def model_score(model, X_train, y_train, X_val, y_val , X_test, y_test):
    print('Train Score:')
    train_score = model.evaluate(X_train, y_train, verbose=0)
    print("MSE: {:.5f} , RMSE: {:.2f}".format(train_score[0], math.sqrt(train_score[0])))

    print('Validation Score:')
    val_score = model.evaluate(X_val, y_val, verbose=0)
    print("MSE: {:.5f} , RMSE: {:.2f}".format (val_score[0], math.sqrt(val_score[0])))

    print('Test Score:')
    test_score = model.evaluate(X_test, y_test, verbose=0)
    print("MSE: {:.5f} , RMSE: {:.2f}".format (test_score[0], math.sqrt(test_score[0])))


model_score(model, trainX, trainY ,valX, valY , testX, testY)
# Out:
# Train Score:
# MSE: 0.00015 , RMSE: 0.01
# Validation Score:
# MSE: 0.00034 , RMSE: 0.02
# Test Score:
# MSE: 0.00022 , RMSE: 0.01

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'mean_squared_error', 'val_loss', 'val_mean_squared_error'])

# %%
plt.plot(history.history['loss'])  # plotting train loss
plt.plot(history.history['val_loss'])  # plotting validation loss

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
pred = model.predict(testX)

pred = scaler.inverse_transform(pred)
print(pred[:10])
# Out:
# [[37.75061 ]
#  [37.561756]
#  [37.3132  ]
#  [37.193874]
#  [37.03475 ]
#  [36.67664 ]
#  [36.68659 ]
#  [36.616943]
#  [36.09944 ]
#  [36.089485]]

# %%
testY_actual = testY.reshape(testY.shape[0] , 1)
testY_actual = scaler.inverse_transform(testY_actual)
print(testY_actual[:10])
# Out:
# [[37.48]
#  [37.23]
#  [37.11]
#  [36.95]
#  [36.59]
#  [36.6 ]
#  [36.53]
#  [36.01]
#  [36.  ]
#  [36.94]]

# %%
plt.plot(testY_actual , 'b')
plt.plot(pred , 'r')

plt.xlabel('Time')
plt.ylabel('Yahoo Stock Prices')
plt.title('Check the performance of the model with time')
plt.legend(['Actual', 'Predicted'], loc='upper left')

plt.grid(True)
plt.figure(figsize=(10, 10)) 
plt.show()
